# %%
import pandas as pd
import numpy as np

# %%
Custom_na_vals = ['NA', 'Missing'] 
df = pd.read_csv('Pandas/survey_results_public.csv',index_col='Respondent', na_values= Custom_na_vals)

# %%
schema_df = pd.read_csv('Pandas/survey_results_schema.csv',index_col='Column')

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].value_counts()
# Out:
# 5                     7047
# 10                    6777
# 6                     6179
# 4                     5729
# 8                     5361
# 7                     5320
# 3                     5179
# 2                     3974
# 15                    3942
# 20                    3636
# 12                    3530
# 9                     3360
# 11                    2265
# 14                    2126
# 13                    2036
# 18                    1900
# 1                     1814
# 25                    1657
# 16                    1593
# 30                    1532
# Less than 1 year      1367
# 17                    1349
# 19                    1018
# 22                    1016
# 35                     873
# 23                     745
# 21                     715
# 24                     693
# 40                     497
# 28                     465
# 32                     420
# 26                     409
# 27                     408
# 33                     353
# ...

# %%
# checking how many years =  More than 50 years
yearfilt = df['YearsCode'] == 'More than 50 years'


#df.loc[yearfilt].count() -- it gives the count of values in every coulumn when the filter is applied
# Out:
# MainBranch                122
# Hobbyist                  126
# OpenSourcer               126
# OpenSource                118
# Employment                121
# Country                   126
# Student                   116
# EdLevel                   112
# UndergradMajor             93
# EduOther                  109
# OrgSize                    48
# DevType                    53
# YearsCode                 126
# Age1stCode                125
# YearsCodePro              103
# CareerSat                  48
# JobSat                     45
# MgrIdiot                   23
# MgrMoney                   22
# MgrWant                    23
# JobSeek                    52
# LastHireDate               52
# LastInt                    37
# FizzBuzz                   48
# JobFactors                 49
# ResumeUpdate               45
# CurrencySymbol             45
# CurrencyDesc               45
# CompTotal                  26
# CompFreq                   28
# ConvertedComp              24
# ...

# %%
df.loc[yearfilt]

# so we have 126 rows with 'More than 50 years' in YearsCode column
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 840                    I am a student who is learning to code       No
# 3604        I used to be a developer by profession, but no...      Yes
# 5417        I used to be a developer by profession, but no...      Yes
# 7054                           I am a developer by profession      Yes
# 7488        I used to be a developer by profession, but no...      Yes
# ...                                                       ...      ...
# 87755                          I am a developer by profession       No
# 4625                                                      NaN      Yes
# 50685                                                     NaN       No
# 62177                                                     NaN      Yes
# 86566                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['YearsCode'].replace('Less than 1 year',0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'].value_counts()
# Out:
# 5.0     7047
# 10.0    6777
# 6.0     6179
# 4.0     5729
# 8.0     5361
# 7.0     5320
# 3.0     5179
# 2.0     3974
# 15.0    3942
# 20.0    3636
# 12.0    3530
# 9.0     3360
# 11.0    2265
# 14.0    2126
# 13.0    2036
# 18.0    1900
# 1.0     1814
# 25.0    1657
# 16.0    1593
# 30.0    1532
# 0.0     1367
# 17.0    1349
# 19.0    1018
# 22.0    1016
# 35.0     873
# 23.0     745
# 21.0     715
# 24.0     693
# 40.0     497
# 28.0     465
# 32.0     420
# 26.0     409
# 27.0     408
# 33.0     353
# 38.0     340
# 34.0     327
# 37.0     321
# 36.0     308
# 29.0     234
# 31.0     202
# 39.0     170
# 51.0     126
# 42.0     115
# 45.0     113
# 41.0      92
# 43.0      83
# 44.0      52
# 50.0      51
# 47.0      36
# 48.0      31
# 46.0      27
# 49.0      25
# Name: YearsCode, dtype: int64

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df1 = pd.read_csv('Pandas/ETH_1h.csv')

# %%
df1.head(5)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df1['Date'].dtypes
# Out:
# dtype('O')

# %%
df1['Date'] = pd.to_datetime(df1['Date'], format = '%Y-%m-%d %I-%p')

#conversion of pandas str object to datetime object

# %%
df1['Date'].head(5)
# Out:
# 0   2020-03-13 20:00:00
# 1   2020-03-13 19:00:00
# 2   2020-03-13 18:00:00
# 3   2020-03-13 17:00:00
# 4   2020-03-13 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
df1['Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df1.loc[0, 'Date'].day_name()

# To get the day name for a corresponding date use day_name()
# Out:
# 'Friday'

# %%
# converting to datetimec while loading

dformat_fun = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df2 =  pd.read_csv('data/ETH_1h.csv', parse_dates=['Date'], date_parser = dformat_fun )

#parse_dates give column name  date_parser= give format
# Out:
# C:\Users\Sathyavathi\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
# get the day for the entire date column after converting it to datetime object

df1['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
# creating new column for day name
df1['DayOfWeek'] = df1['Date'].dt.day_name()
df1.head(5)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
# use min and max to get the earliest and latest date

df1['Date'].min()
df1['Date'].max()

# time period or time delat of the dataset
df1['Date'].max()-df1['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# Filtering in datetime

# for all the rows where the year is 2020 or more

filt = (df1['Date'] >= '2020')
df1.loc[filt]

#for 2019 date we need to specify upper limit also

# filt = (df1['Date'] >= '2019') & (df1['Date'] < '2019')
# we can also give datetime in comparison to_datetime
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
df1.set_index('Date', inplace=True)
# setting date column as index

# %%
#slicing based on date index column instead of filtering
df1['2020']
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
# [1749 rows x 6 columns]

# %%
df1['2020'].count()
# Out:
# Symbol       1749
# Open         1749
# High         1749
# Low          1749
# Close        1749
# Volume       1749
# DayOfWeek    1749
# dtype: int64

# %%
# monthly slicing
df1['2020-01':'2020-02']

# here both dates inclusive


# jan to feb only

# df1['2020-02':'2020-01'] does not work
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
# [1440 rows x 6 columns]

# %%
df1['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
df1['2020-01-01']['High'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-01-01'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-2fd286ef7f0f> in <module>
# ----> 1 df1['2020-01-01']['High'].max()
#
# ...

# %%
#Resampling
#  https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects

df1['High'].resample('D').max()

#it gives the max value of High column for each day
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
# assign it to a variable (df variable)
Max_per_day = df1['High'].resample('D').max()

Max_per_day['2020-01-01']
# Out:
# 132.68

# %%
df1['Date']
# error as it is the index now
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-a9f99ca8d4cc> in <module>
# ----> 1 df1['Date']
#
# ...

# %%
# %matplotlib inline

# you might require to install matplotlib in the virtual env

# %%
Max_per_day.plot()
# we are not using pyplot here

# %%
#resample for entire dataframe

df1.resample('W').max()
# Out:
#             Symbol    Open    High     Low   Close       Volume  DayOfWeek
# Date
# 2017-07-02  ETHUSD  292.54  293.73  284.87  292.54   7081816.11     Sunday
# 2017-07-09  ETHUSD  285.00  285.00  282.31  282.58   6082287.50  Wednesday
# 2017-07-16  ETHUSD  238.81  240.33  238.00  238.47  23582117.48  Wednesday
# 2017-07-23  ETHUSD  245.55  249.40  234.97  245.55  31082353.62  Wednesday
# 2017-07-30  ETHUSD  229.96  229.99  229.60  229.96   9214814.73  Wednesday
# ...            ...     ...     ...     ...     ...          ...        ...
# 2020-02-16  ETHUSD  286.39  290.00  285.10  286.39  13323454.31  Wednesday
# 2020-02-23  ETHUSD  285.30  287.13  282.00  285.30  12085035.32  Wednesday
# 2020-03-01  ETHUSD  276.91  278.13  274.28  276.91  19074673.60  Wednesday
# 2020-03-08  ETHUSD  247.62  253.01  245.01  247.62   8804126.61  Wednesday
# 2020-03-15  ETHUSD  207.79  208.65  205.83  207.79  19731142.71  Wednesday
#
# [142 rows x 7 columns]

# %%
# using agg function to get different agg values for the mentioned column

df1.resample('W').agg({'High':'max', 'Low':'min', 'Volume':'sum'})

# here key is column name and its value is the agg fn we want
# Out:
#               High     Low        Volume
# Date
# 2017-07-02  293.73  253.23  8.084631e+07
# 2017-07-09  285.00  231.25  2.246746e+08
# 2017-07-16  240.33  130.26  5.017750e+08
# 2017-07-23  249.40  153.25  7.221637e+08
# 2017-07-30  229.99  178.03  2.657305e+08
# ...            ...     ...           ...
# 2020-02-16  290.00  216.31  3.912867e+08
# 2020-02-23  287.13  242.36  3.067838e+08
# 2020-03-01  278.13  209.26  3.693920e+08
# 2020-03-08  253.01  196.00  2.736569e+08
# 2020-03-15  208.65   90.00  4.983998e+08
#
# [142 rows x 3 columns]
